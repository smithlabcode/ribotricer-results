# %%
# %pylab inline
from collections import OrderedDict

import pandas as pd
from pysradb import SRAdb, expand_sample_attribute_columns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
db = SRAdb('/staging/as/skchoudh/SRAmetadb.sqlite')

# %%
assembly_common_name_map = {'mm10': 'mouse', 'hg38': 'human'}

sheet_name = 'hg38'
excel_df = pd.read_excel('../data/datasets_info.xlsx', sheet_name=sheet_name)

# %%
excel_df
# Out:
#         GEO        SRA RIBO sample                       RNA sample  \
# 0  GSE35469  SRP010679   SRX118286                        SRX118285
# 1       NaN  SRP029589   SRX345309                        SRX345311
# 2  GSE73136  SRP063852  SRX1254413  SRX426378 (SRP028887, GSE49831)
# 3  GSE94454  SRP098789  SRX2536421                       SRX2536426
# 4  GSE96716  SRP102021  SRX2647167                       SRX2647164
# 5  GSE87328  SRP090415  SRX2189157                       SRX2189154
# 6  GSE89183  SRP092068  SRX2268404                       SRX2268396
# 7  GSE96714  SRP102020  SRX2647162                       SRX2647160
#
#      read lengths         offsets           RIBO adapter        RNA adapter  \
# 0        28,29,30        12,13,13             CTGTAGGCAC         CTGTAGGCAC
# 1        29,30,32        12,12,13      CTGTAGGCACCATCAAT  CTGTAGGCACCATCAAT
# 2        28,29,30        12,12,12                   None               None
# 3           28,30           12,13      CTGTAGGCACCATCAAT  CTGTAGGCACCATCAAT
# 4     28,29,30,31     12,12,12,12  TCGTATGCCGTCTTCTGCTTG               None
# 5  26,27,28,29,30  12,12,12,12,12      CTGTAGGCACCATCAAT  AGATCGGAAGAGCACAC
# 6  26,27,28,29,30  12,12,12,12,12  AGATCGGAAGAGCACACGTCT               None
# 7           29,30           12,12  TCGTATGCCGTCTTCTGCTTG               None
#
#   RIBO strandedness RNA strandedness  \
# 0           forward          forward
# 1           forward          forward
# 2           forward          forward
# 3           forward          forward
# 4           forward          forward
# 5           forward          reverse
# 6           forward          reverse
# 7           forward               no
#
#    AUC(RiboCop/RiboCode/RiboTaper/ORFscore)  metagene_coherence_ribocop
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 6                                       NaN                         NaN
# 7                                       NaN                         NaN

# %%
all_dfs =  OrderedDict()

# %%
srp = 'SRP010679'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df.loc[df.experiment_title.str.contains('Footprint'), 'assay'] = 'ribo'
df = expand_sample_attribute_columns(df)
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#    study_accession experiment_accession  \
# 0        SRP010679            SRX118285
# 1        SRP010679            SRX118286
# 2        SRP010679            SRX118287
# 3        SRP010679            SRX118288
# 4        SRP010679            SRX118289
# 5        SRP010679            SRX118290
# 6        SRP010679            SRX118291
# 7        SRP010679            SRX118292
# 8        SRP010679            SRX118293
# 9        SRP010679            SRX118294
# 10       SRP010679            SRX118295
# 11       SRP010679            SRX118296
#
#                                      experiment_title  \
# 0   GSM869036: mRNA-seq for vehicle treated PC3 ce...
# 1   GSM869037: Footprint for vehicle treated PC3 c...
# 2   GSM869038: mRNA-seq for rapamcyin treated PC3 ...
# 3   GSM869039: Footprint for rapamcyin treated PC3...
# 4   GSM869040: mRNA-seq for PP242 treated PC3 cell...
# 5   GSM869041: Footprint for PP242 treated PC3 cel...
# 6   GSM869042: mRNA-seq for vehicle treated PC3 ce...
# 7   GSM869043: Footprint for vehicle treated PC3 c...
# 8   GSM869044: mRNA-seq for rapamcyin treated PC3 ...
# 9   GSM869045: Footprint for rapamcyin treated PC3...
# 10  GSM869046: mRNA-seq for PP242 treated PC3 cell...
# 11  GSM869047: Footprint for PP242 treated PC3 cel...
#
#         experiment_attribute  \
# 0   GEO Accession: GSM869036
# 1   GEO Accession: GSM869037
# 2   GEO Accession: GSM869038
# 3   GEO Accession: GSM869039
# 4   GEO Accession: GSM869040
# 5   GEO Accession: GSM869041
# 6   GEO Accession: GSM869042
# 7   GEO Accession: GSM869043
# 8   GEO Accession: GSM869044
# 9   GEO Accession: GSM869045
# 10  GEO Accession: GSM869046
# 11  GEO Accession: GSM869047
#
#                                      sample_attribute run_accession  taxon_id  \
# 0   source_name: PC3 human prostate cancer cells |...     SRR403882      9606
# 1   source_name: PC3 human prostate cancer cells |...     SRR403883      9606
# 2   source_name: PC3 human prostate cancer cells |...     SRR403884      9606
# 3   source_name: PC3 human prostate cancer cells |...     SRR403885      9606
# 4   source_name: PC3 human prostate cancer cells |...     SRR403886      9606
# 5   source_name: PC3 human prostate cancer cells |...     SRR403887      9606
# 6   source_name: PC3 human prostate cancer cells |...     SRR403888      9606
# 7   source_name: PC3 human prostate cancer cells |...     SRR403889      9606
# 8   source_name: PC3 human prostate cancer cells |...     SRR403890      9606
# 9   source_name: PC3 human prostate cancer cells |...     SRR403891      9606
# 10  source_name: PC3 human prostate cancer cells |...     SRR403892      9606
# 11  source_name: PC3 human prostate cancer cells |...     SRR403893      9606
#
#    library_selection library_layout library_strategy    ...      \
# 0               cDNA      SINGLE -           RNA-Seq    ...
# 1               cDNA      SINGLE -           RNA-Seq    ...
# 2               cDNA      SINGLE -           RNA-Seq    ...
# 3               cDNA      SINGLE -           RNA-Seq    ...
# 4               cDNA      SINGLE -           RNA-Seq    ...
# 5               cDNA      SINGLE -           RNA-Seq    ...
# 6               cDNA      SINGLE -           RNA-Seq    ...
# 7               cDNA      SINGLE -           RNA-Seq    ...
# 8               cDNA      SINGLE -           RNA-Seq    ...
# 9               cDNA      SINGLE -           RNA-Seq    ...
# 10              cDNA      SINGLE -           RNA-Seq    ...
# 11              cDNA      SINGLE -           RNA-Seq    ...
#
#                                          library_name       bases     spots  \
# 0   GSM869036: mRNA-seq for vehicle treated PC3 ce...   886121960  22153049
# 1   GSM869037: Footprint for vehicle treated PC3 c...   830504160  20762604
# 2   GSM869038: mRNA-seq for rapamcyin treated PC3 ...   875152240  21878806
# 3   GSM869039: Footprint for rapamcyin treated PC3...   789711800  19742795
# 4   GSM869040: mRNA-seq for PP242 treated PC3 cell...   786234960  19655874
# 5   GSM869041: Footprint for PP242 treated PC3 cel...   788273800  19706845
# 6   GSM869042: mRNA-seq for vehicle treated PC3 ce...   979031600  24475790
# 7   GSM869043: Footprint for vehicle treated PC3 c...   975917920  24397948
# 8   GSM869044: mRNA-seq for rapamcyin treated PC3 ...   764698520  19117463
# 9   GSM869045: Footprint for rapamcyin treated PC3...  1017802720  25445068
# 10  GSM869046: mRNA-seq for PP242 treated PC3 cell...  1030229480  25755737
# 11  GSM869047: Footprint for PP242 treated PC3 cel...  1011667000  25291675
#
#     adapter_spec avg_read_length  assay cell_line             sample_type  \
# 0           None            40.0    rna       pc3               polya rna
# 1           None            40.0   ribo       pc3  ribosome protected rna
# 2           None            40.0    rna       pc3               polya rna
# 3           None            40.0   ribo       pc3  ribosome protected rna
# 4           None            40.0    rna       pc3               polya rna
# 5           None            40.0   ribo       pc3  ribosome protected rna
# 6           None            40.0    rna       pc3               polya rna
# 7           None            40.0   ribo       pc3  ribosome protected rna
# 8           None            40.0    rna       pc3               polya rna
# 9           None            40.0   ribo       pc3  ribosome protected rna
# 10          None            40.0    rna       pc3               polya rna
# 11          None            40.0   ribo       pc3  ribosome protected rna
#
#                         source_name  treatment
# 0   pc3 human prostate cancer cells    vehicle
# 1   pc3 human prostate cancer cells    vehicle
# 2   pc3 human prostate cancer cells  rapamycin
# 3   pc3 human prostate cancer cells  rapamycin
# 4   pc3 human prostate cancer cells      pp242
# 5   pc3 human prostate cancer cells      pp242
# 6   pc3 human prostate cancer cells    vehicle
# 7   pc3 human prostate cancer cells    vehicle
# 8   pc3 human prostate cancer cells  rapamycin
# 9   pc3 human prostate cancer cells  rapamycin
# 10  pc3 human prostate cancer cells      pp242
# 11  pc3 human prostate cancer cells      pp242
#
# [12 rows x 21 columns]

# %%
srp = 'SRP029589'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df.loc[df.experiment_title.str.contains('Ribosome'), 'assay'] = 'ribo'
df = expand_sample_attribute_columns(df)
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#    study_accession experiment_accession  \
# 0        SRP029589            SRX345301
# 1        SRP029589            SRX345302
# 2        SRP029589            SRX345303
# 3        SRP029589            SRX345304
# 4        SRP029589            SRX345305
# 5        SRP029589            SRX345306
# 6        SRP029589            SRX345307
# 7        SRP029589            SRX345308
# 8        SRP029589            SRX345309
# 9        SRP029589            SRX345310
# 10       SRP029589            SRX345311
# 11       SRP029589            SRX345312
#
#                                   experiment_title experiment_attribute  \
# 0   Ribosome profile of G1 synchronized Hela cells                 None
# 1   Ribosome profile of G1 synchronized Hela cells                 None
# 2            RNA-seq of G1 synchronized Hela cells                 None
# 3            RNA-seq of G1 synchronized Hela cells                 None
# 4           Ribosome profile of S-phase Hela cells                 None
# 5           Ribosome profile of S-phase Hela cells                 None
# 6                    RNA-seq of S-phase Hela cells                 None
# 7                    RNA-seq of S-phase Hela cells                 None
# 8           Ribosome profile of mitotic Hela cells                 None
# 9           Ribosome profile of mitotic Hela cells                 None
# 10                   RNA-seq of mitotic Hela cells                 None
# 11                   RNA-seq of mitotic Hela cells                 None
#
#                                      sample_attribute run_accession  taxon_id  \
# 0   cell_line: Hela || sample_type: ribosome footp...     SRR970490      9606
# 1   cell_line: Hela || sample_type: ribosome footp...     SRR970538      9606
# 2   cell_line: Hela || sample_type: total RNA || c...     SRR970543      9606
# 3   cell_line: Hela || sample_type: total RNA || c...     SRR970550      9606
# 4   cell_line: Hela || sample_type: ribosome footp...     SRR970561      9606
# 5   cell_line: Hela || sample_type: ribosome footp...     SRR970565      9606
# 6   cell_line: Hela || sample_type: total RNA || c...     SRR970576      9606
# 7   cell_line: Hela || sample_type: total RNA || c...     SRR970578      9606
# 8   cell_line: Hela || sample_type: ribosome footp...     SRR970587      9606
# 9   cell_line: Hela || sample_type: ribosome footp...     SRR970588      9606
# 10  cell_line: Hela || sample_type: total RNA || c...     SRR970592      9606
# 11  cell_line: Hela || sample_type: total RNA || c...     SRR970593      9606
#
#      library_selection library_layout library_strategy         ...          \
# 0   size fractionation      SINGLE -           RNA-Seq         ...
# 1   size fractionation      SINGLE -           RNA-Seq         ...
# 2   size fractionation      SINGLE -           RNA-Seq         ...
# 3   size fractionation      SINGLE -           RNA-Seq         ...
# 4   size fractionation      SINGLE -           RNA-Seq         ...
# 5   size fractionation      SINGLE -           RNA-Seq         ...
# 6   size fractionation      SINGLE -           RNA-Seq         ...
# 7   size fractionation      SINGLE -           RNA-Seq         ...
# 8   size fractionation      SINGLE -           RNA-Seq         ...
# 9   size fractionation      SINGLE -           RNA-Seq         ...
# 10  size fractionation      SINGLE -           RNA-Seq         ...
# 11  size fractionation      SINGLE -           RNA-Seq         ...
#
#    library_name        bases      spots  adapter_spec avg_read_length  assay  \
# 0          None  10297309122  201908022          None            51.0   ribo
# 1          None  11277817323  221133673          None            51.0   ribo
# 2          None  11133827238  218310338          None            51.0    rna
# 3          None  11425964469  224038519          None            51.0    rna
# 4          None   5630286678  110397778          None            51.0   ribo
# 5          None   9920327475  194516225          None            51.0   ribo
# 6          None   1720332612   33732012          None            51.0    rna
# 7          None   9430688052  184915452          None            51.0    rna
# 8          None   4678903863   91743213          None            51.0   ribo
# 9          None  11151551829  218657879          None            51.0   ribo
# 10         None   5551506366  108853066          None            51.0    rna
# 11         None  10965646221  215012671          None            51.0    rna
#
#    cell_cycle_phase cell_line replicate         sample_type
# 0                g1      hela         1  ribosome footprint
# 1                g1      hela         2  ribosome footprint
# 2                g1      hela         1           total rna
# 3                g1      hela         2           total rna
# 4           s-phase      hela         1  ribosome footprint
# 5           s-phase      hela         2  ribosome footprint
# 6           s-phase      hela         1           total rna
# 7           s-phase      hela         2           total rna
# 8           mitosis      hela         1  ribosome footprint
# 9           mitosis      hela         2  ribosome footprint
# 10          mitosis      hela         1           total rna
# 11          mitosis      hela         2           total rna
#
# [12 rows x 21 columns]

# %%
srp = 'SRP063852'
df = db.sra_metadata(srp)
df['assay'] = 'ribo'
df = expand_sample_attribute_columns(df)
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#   study_accession experiment_accession  \
# 0       SRP063852           SRX1254413
#
#                                     experiment_title  \
# 0  GSM1887643: ribosome profiling; Homo sapiens; ...
#
#         experiment_attribute                          sample_attribute  \
# 0  GEO Accession: GSM1887643  source_name: HEK293 || cell line: HEK293
#
#   run_accession  taxon_id   library_selection library_layout library_strategy  \
# 0    SRR2433794      9606  size fractionation      SINGLE -         miRNA-Seq
#
#    library_source library_name      bases     spots adapter_spec  \
# 0  TRANSCRIPTOMIC         None  916773615  31967082         None
#
#    avg_read_length assay cell_line source_name
# 0        28.678677  ribo    hek293      hek293

# %%
srp = 'SRP098789'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df = expand_sample_attribute_columns(df)

df.loc[df.experiment_title.str.contains('PF-'), 'assay'] = 'ribo'
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#    study_accession experiment_accession  \
# 0        SRP098789           SRX2536403
# 1        SRP098789           SRX2536404
# 2        SRP098789           SRX2536405
# 3        SRP098789           SRX2536406
# 4        SRP098789           SRX2536407
# 5        SRP098789           SRX2536408
# 6        SRP098789           SRX2536409
# 7        SRP098789           SRX2536410
# 8        SRP098789           SRX2536411
# 9        SRP098789           SRX2536412
# 10       SRP098789           SRX2536413
# 11       SRP098789           SRX2536414
# 12       SRP098789           SRX2536415
# 13       SRP098789           SRX2536416
# 14       SRP098789           SRX2536417
# 15       SRP098789           SRX2536418
# 16       SRP098789           SRX2536419
# 17       SRP098789           SRX2536420
# 18       SRP098789           SRX2536421
# 19       SRP098789           SRX2536422
# 20       SRP098789           SRX2536423
# 21       SRP098789           SRX2536424
# 22       SRP098789           SRX2536425
# 23       SRP098789           SRX2536426
# 24       SRP098789           SRX2536427
# 25       SRP098789           SRX2536428
#
#                                      experiment_title  \
# 0   GSM2475997: 1.5 Ã‚ÂµM PF-067446846, 10 min, re...
# 1   GSM2475998: 1.5 Ã‚ÂµM PF-067446846, 10 min, re...
# 2   GSM2475999: 1.5 Ã‚ÂµM PF-067446846, 10 min, re...
# 3   GSM2476000: 0.3 Ã‚ÂµM PF-067446846, 10 min, re...
# 4   GSM2476001: 0.3 Ã‚ÂµM PF-067446846, 10 min, re...
# 5   GSM2476002: 0.3 Ã‚ÂµM PF-067446846, 10 min, re...
# 6   GSM2476003: vehicle, 10 min rep 1; Homo sapien...
# 7   GSM2476004: vehicle, 10 min rep 2; Homo sapien...
# 8   GSM2476005: vehicle, 10 min rep 3; Homo sapien...
# 9   GSM2476006: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 10  GSM2476007: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 11  GSM2476008: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 12  GSM2476009: 0.3 Ã‚ÂµM PF-067446846, 60 min, re...
# 13  GSM2476010: 0.3 Ã‚ÂµM PF-067446846, 60 min, re...
# 14  GSM2476011: 0.3 Ã‚ÂµM PF-067446846, 60 min, re...
# 15  GSM2476012: vehicle, 60 min rep 1; Homo sapien...
# 16  GSM2476013: vehicle, 60 min rep 2; Homo sapien...
# 17  GSM2476014: vehicle, 60 min rep 3; Homo sapien...
# 18  GSM2476015: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 19  GSM2476016: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 20  GSM2476017: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 21  GSM2476018: 1.5 Ã‚ÂµM PF-067446846, 60 min, re...
# 22  GSM2476019: vehicle, 60 min, rep 4 -riboseq; H...
# 23  GSM2476020: vehicle, 60 min, rep 4-mRNAseq; Ho...
# 24  GSM2476021: vehicle, 60 min, rep 5 -riboseq; H...
# 25  GSM2476022: vehicle, 60 min, rep 5-mRNAseq; Ho...
#
#          experiment_attribute  \
# 0   GEO Accession: GSM2475997
# 1   GEO Accession: GSM2475998
# 2   GEO Accession: GSM2475999
# 3   GEO Accession: GSM2476000
# 4   GEO Accession: GSM2476001
# 5   GEO Accession: GSM2476002
# 6   GEO Accession: GSM2476003
# 7   GEO Accession: GSM2476004
# 8   GEO Accession: GSM2476005
# 9   GEO Accession: GSM2476006
# 10  GEO Accession: GSM2476007
# 11  GEO Accession: GSM2476008
# 12  GEO Accession: GSM2476009
# 13  GEO Accession: GSM2476010
# 14  GEO Accession: GSM2476011
# 15  GEO Accession: GSM2476012
# 16  GEO Accession: GSM2476013
# 17  GEO Accession: GSM2476014
# 18  GEO Accession: GSM2476015
# 19  GEO Accession: GSM2476016
# 20  GEO Accession: GSM2476017
# 21  GEO Accession: GSM2476018
# 22  GEO Accession: GSM2476019
# 23  GEO Accession: GSM2476020
# 24  GEO Accession: GSM2476021
# 25  GEO Accession: GSM2476022
#
#                                      sample_attribute run_accession  taxon_id  \
# 0   source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_10 mi...    SRR5227288      9606
# 1   source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_10 mi...    SRR5227289      9606
# 2   source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_10 mi...    SRR5227290      9606
# 3   source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_10 mi...    SRR5227291      9606
# 4   source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_10 mi...    SRR5227292      9606
# 5   source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_10 mi...    SRR5227293      9606
# 6   source_name: Huh7_vehicle_10 min_ribo-seq || c...    SRR5227294      9606
# 7   source_name: Huh7_vehicle_10 min_ribo-seq || c...    SRR5227295      9606
# 8   source_name: Huh7_vehicle_10 min_ribo-seq || c...    SRR5227296      9606
# 9   source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227297      9606
# 10  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227298      9606
# 11  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227299      9606
# 12  source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_60 mi...    SRR5227300      9606
# 13  source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_60 mi...    SRR5227301      9606
# 14  source_name: Huh7_0.3 Ã‚ÂµM PF-067446846_60 mi...    SRR5227302      9606
# 15  source_name: Huh7_vehicle_60 min_ribo-seq || c...    SRR5227303      9606
# 16  source_name: Huh7_vehicle_60 min_ribo-seq || c...    SRR5227304      9606
# 17  source_name: Huh7_vehicle_60 min_ribo-seq || c...    SRR5227305      9606
# 18  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227306      9606
# 19  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227307      9606
# 20  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227308      9606
# 21  source_name: Huh7_1.5 Ã‚ÂµM PF-067446846_60 mi...    SRR5227309      9606
# 22  source_name: Huh7_vehicle_60 min_ribo-seq || c...    SRR5227310      9606
# 23  source_name: Huh7_vehicle_60 min_RNA-seq || ce...    SRR5227311      9606
# 24  source_name: Huh7_vehicle_60 min_ribo-seq || c...    SRR5227312      9606
# 25  source_name: Huh7_vehicle_60 min_RNA-seq || ce...    SRR5227313      9606
#
#    library_selection library_layout library_strategy      ...        \
# 0              other      SINGLE -             OTHER      ...
# 1              other      SINGLE -             OTHER      ...
# 2              other      SINGLE -             OTHER      ...
# 3              other      SINGLE -             OTHER      ...
# 4              other      SINGLE -             OTHER      ...
# 5              other      SINGLE -             OTHER      ...
# 6              other      SINGLE -             OTHER      ...
# 7              other      SINGLE -             OTHER      ...
# 8              other      SINGLE -             OTHER      ...
# 9              other      SINGLE -             OTHER      ...
# 10             other      SINGLE -             OTHER      ...
# 11             other      SINGLE -             OTHER      ...
# 12             other      SINGLE -             OTHER      ...
# 13             other      SINGLE -             OTHER      ...
# 14             other      SINGLE -             OTHER      ...
# 15             other      SINGLE -             OTHER      ...
# 16             other      SINGLE -             OTHER      ...
# 17             other      SINGLE -             OTHER      ...
# 18             other      SINGLE -             OTHER      ...
# 19              cDNA      SINGLE -           RNA-Seq      ...
# 20             other      SINGLE -             OTHER      ...
# 21              cDNA      SINGLE -           RNA-Seq      ...
# 22             other      SINGLE -             OTHER      ...
# 23              cDNA      SINGLE -           RNA-Seq      ...
# 24             other      SINGLE -             OTHER      ...
# 25              cDNA      SINGLE -           RNA-Seq      ...
#
#    library_name       bases     spots  adapter_spec avg_read_length  assay  \
# 0          None  2104142750  42082855          None            50.0   ribo
# 1          None  2082873050  41657461          None            50.0   ribo
# 2          None  2023148650  40462973          None            50.0   ribo
# 3          None  2057165950  41143319          None            50.0   ribo
# 4          None  3027621850  60552437          None            50.0   ribo
# 5          None  2135456900  42709138          None            50.0   ribo
# 6          None  3800106100  76002122          None            50.0    rna
# 7          None  2306857400  46137148          None            50.0    rna
# 8          None  2636889200  52737784          None            50.0    rna
# 9          None  3019068250  60381365          None            50.0   ribo
# 10         None  2466719600  49334392          None            50.0   ribo
# 11         None  2438310650  48766213          None            50.0   ribo
# 12         None  1502168100  30043362          None            50.0   ribo
# 13         None  2456475600  49129512          None            50.0   ribo
# 14         None  2212909000  44258180          None            50.0   ribo
# 15         None  2547808900  50956178          None            50.0    rna
# 16         None  2356952850  47139057          None            50.0    rna
# 17         None  2420251700  48405034          None            50.0    rna
# 18         None  2936988765  57588015          None            51.0   ribo
# 19         None  3390530541  66480991          None            51.0   ribo
# 20         None  3345152067  65591217          None            51.0   ribo
# 21         None  2043193263  40062613          None            51.0   ribo
# 22         None  3384542835  66363585          None            51.0    rna
# 23         None  3249730455  63720205          None            51.0    rna
# 24         None  2961321834  58065134          None            51.0    rna
# 25         None  3540569481  69422931          None            51.0    rna
#
#    cell_line library_type                                  source_name  \
# 0       huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_10 min_ribo-seq
# 1       huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_10 min_ribo-seq
# 2       huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_10 min_ribo-seq
# 3       huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_10 min_ribo-seq
# 4       huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_10 min_ribo-seq
# 5       huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_10 min_ribo-seq
# 6       huh7     ribo-seq                 huh7_vehicle_10 min_ribo-seq
# 7       huh7     ribo-seq                 huh7_vehicle_10 min_ribo-seq
# 8       huh7     ribo-seq                 huh7_vehicle_10 min_ribo-seq
# 9       huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_60 min_ribo-seq
# 10      huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_60 min_ribo-seq
# 11      huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_60 min_ribo-seq
# 12      huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_60 min_ribo-seq
# 13      huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_60 min_ribo-seq
# 14      huh7     ribo-seq  huh7_0.3 ã‚âµm pf-067446846_60 min_ribo-seq
# 15      huh7     ribo-seq                 huh7_vehicle_60 min_ribo-seq
# 16      huh7     ribo-seq                 huh7_vehicle_60 min_ribo-seq
# 17      huh7     ribo-seq                 huh7_vehicle_60 min_ribo-seq
# 18      huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_60 min_ribo-seq
# 19      huh7    polya-seq   huh7_1.5 ã‚âµm pf-067446846_60 min_rna-seq
# 20      huh7     ribo-seq  huh7_1.5 ã‚âµm pf-067446846_60 min_ribo-seq
# 21      huh7    polya-seq   huh7_1.5 ã‚âµm pf-067446846_60 min_rna-seq
# 22      huh7     ribo-seq                 huh7_vehicle_60 min_ribo-seq
# 23      huh7    polya-seq                  huh7_vehicle_60 min_rna-seq
# 24      huh7     ribo-seq                 huh7_vehicle_60 min_ribo-seq
# 25      huh7    polya-seq                  huh7_vehicle_60 min_rna-seq
#
#    treatment_time
# 0          10 min
# 1          10 min
# 2          10 min
# 3          10 min
# 4          10 min
# 5          10 min
# 6          10 min
# 7          10 min
# 8          10 min
# 9          60 min
# 10         60 min
# 11         60 min
# 12         60 min
# 13         60 min
# 14         60 min
# 15         60 min
# 16         60 min
# 17         60 min
# 18         60 min
# 19         60 min
# 20         60 min
# 21         60 min
# 22         60 min
# 23         60 min
# 24         60 min
# 25         60 min
#
# [26 rows x 21 columns]

# %%
srp = 'SRP102021'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df = expand_sample_attribute_columns(df)
df.loc[df.experiment_title.str.contains('ribo'), 'assay'] = 'ribo'
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#   study_accession experiment_accession  \
# 0       SRP102021           SRX2647164
# 1       SRP102021           SRX2647165
# 2       SRP102021           SRX2647166
# 3       SRP102021           SRX2647167
#
#                                  experiment_title       experiment_attribute  \
# 0    GSM2538901: PC9.C.rna; Homo sapiens; RNA-Seq  GEO Accession: GSM2538901
# 1  GSM2538902: H1933.C.rna; Homo sapiens; RNA-Seq  GEO Accession: GSM2538902
# 2     GSM2538903: PC9.C.ribo; Homo sapiens; OTHER  GEO Accession: GSM2538903
# 3   GSM2538904: H1933.C.ribo; Homo sapiens; OTHER  GEO Accession: GSM2538904
#
#                                     sample_attribute run_accession  taxon_id  \
# 0  source_name: PC9 || cell line: PC9 || treatmen...    SRR5350742      9606
# 1  source_name: H1933 || cell line: H1933 || trea...    SRR5350743      9606
# 2  source_name: PC9 || cell line: PC9 || treatmen...    SRR5350744      9606
# 3  source_name: H1933 || cell line: H1933 || trea...    SRR5350745      9606
#
#   library_selection library_layout library_strategy  library_source  \
# 0              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 1              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 2             other      SINGLE -             OTHER  TRANSCRIPTOMIC
# 3             other      SINGLE -             OTHER  TRANSCRIPTOMIC
#
#   library_name       bases     spots adapter_spec  avg_read_length assay  \
# 0         None   577112685  11315935         None             51.0   rna
# 1         None   480769707   9426857         None             51.0   rna
# 2         None  3651884427  71605577         None             51.0  ribo
# 3         None  3972411420  77890420         None             51.0  ribo
#
#   cell_line source_name treatment
# 0       pc9         pc9   control
# 1     h1933       h1933   control
# 2       pc9         pc9   control
# 3     h1933       h1933   control

# %%
srp = 'SRP090415'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df = expand_sample_attribute_columns(df)
df.loc[df.experiment_title.str.contains('Ribosome'), 'assay'] = 'ribo'
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#   study_accession experiment_accession  \
# 0       SRP090415           SRX2189154
# 1       SRP090415           SRX2189155
# 2       SRP090415           SRX2189156
# 3       SRP090415           SRX2189157
# 4       SRP090415           SRX2189158
# 5       SRP090415           SRX2189159
#
#                                     experiment_title  \
# 0  GSM2327829: mRNA sequencing of HCT116 cells up...
# 1  GSM2327830: mRNA sequencing of control HCT116 ...
# 2  GSM2327825: Ribosome profiling of HCT116 cells...
# 3  GSM2327826: Ribosome profiling of HCT116 cells...
# 4  GSM2327827: Ribosome profiling of control HCT1...
# 5  GSM2327828: Ribosome profiling of control HCT1...
#
#         experiment_attribute  \
# 0  GEO Accession: GSM2327829
# 1  GEO Accession: GSM2327830
# 2  GEO Accession: GSM2327825
# 3  GEO Accession: GSM2327826
# 4  GEO Accession: GSM2327827
# 5  GEO Accession: GSM2327828
#
#                                     sample_attribute run_accession  taxon_id  \
# 0  source_name: colorectal carcinoma cell line ||...    SRR4293697      9606
# 1  source_name: colorectal carcinoma cell line ||...    SRR4293698      9606
# 2  source_name: colorectal carcinoma cell line ||...    SRR4293693      9606
# 3  source_name: colorectal carcinoma cell line ||...    SRR4293694      9606
# 4  source_name: colorectal carcinoma cell line ||...    SRR4293695      9606
# 5  source_name: colorectal carcinoma cell line ||...    SRR4293696      9606
#
#   library_selection library_layout library_strategy  ...   library_name  \
# 0              cDNA      SINGLE -           RNA-Seq  ...           None
# 1              cDNA      SINGLE -           RNA-Seq  ...           None
# 2             other      SINGLE -             OTHER  ...           None
# 3             other      SINGLE -             OTHER  ...           None
# 4             other      SINGLE -             OTHER  ...           None
# 5             other      SINGLE -             OTHER  ...           None
#
#          bases      spots  adapter_spec avg_read_length  assay cell_line  \
# 0   4234533191   56101600          None       75.479722    rna    hct116
# 1   4383934151   58076562          None       75.485428    rna    hct116
# 2  13601298732  178964457          None       76.000000   ribo    hct116
# 3  14046557044  184823119          None       76.000000   ribo    hct116
# 4  15166827596  199563521          None       76.000000   ribo    hct116
# 5  17103204616  225042166          None       76.000000   ribo    hct116
#
#               phenotype                     source_name tissue
# 0  colorectal carcinoma  colorectal carcinoma cell line  colon
# 1  colorectal carcinoma  colorectal carcinoma cell line  colon
# 2  colorectal carcinoma  colorectal carcinoma cell line  colon
# 3  colorectal carcinoma  colorectal carcinoma cell line  colon
# 4  colorectal carcinoma  colorectal carcinoma cell line  colon
# 5  colorectal carcinoma  colorectal carcinoma cell line  colon
#
# [6 rows x 21 columns]

# %%
srp = 'SRP092068'
df = db.sra_metadata(srp)
#df = expand_sample_attribute_columns(df)
df['assay'] = 'rna'
df
# Out:
#    study_accession experiment_accession experiment_title experiment_attribute  \
# 0        SRP092068           SRX2268396             None                 None
# 1        SRP092068           SRX2268397             None                 None
# 2        SRP092068           SRX2268398             None                 None
# 3        SRP092068           SRX2268399             None                 None
# 4        SRP092068           SRX2268400             None                 None
# 5        SRP092068           SRX2268401             None                 None
# 6        SRP092068           SRX2268402             None                 None
# 7        SRP092068           SRX2268403             None                 None
# 8        SRP092068           SRX2268404             None                 None
# 9        SRP092068           SRX2268405             None                 None
# 10       SRP092068           SRX2268406             None                 None
# 11       SRP092068           SRX2268407             None                 None
# 12       SRP092068           SRX2268408             None                 None
# 13       SRP092068           SRX2268409             None                 None
#
#    sample_attribute run_accession  taxon_id library_selection library_layout  \
# 0              None    SRR4450319         0              None           None
# 1              None    SRR4450320         0              None           None
# 2              None    SRR4450321         0              None           None
# 3              None    SRR4450322         0              None           None
# 4              None    SRR4450323         0              None           None
# 5              None    SRR4450324         0              None           None
# 6              None    SRR4450325         0              None           None
# 7              None    SRR4450326         0              None           None
# 8              None    SRR4450327         0              None           None
# 9              None    SRR4450328         0              None           None
# 10             None    SRR4450329         0              None           None
# 11             None    SRR4450330         0              None           None
# 12             None    SRR4450331         0              None           None
# 13             None    SRR4450332         0              None           None
#
#    library_strategy library_source library_name       bases     spots  \
# 0              None           None         None  1082460850  21649217
# 1              None           None         None   892411700  17848234
# 2              None           None         None   938725900  18774518
# 3              None           None         None   903547100  18070942
# 4              None           None         None  1026896450  20537929
# 5              None           None         None   786340550  15726811
# 6              None           None         None   965706550  19314131
# 7              None           None         None  1078819900  21576398
# 8              None           None         None   866353000  17327060
# 9              None           None         None   853020650  17060413
# 10             None           None         None   834518950  16690379
# 11             None           None         None   718613700  14372274
# 12             None           None         None   814112000  16282240
# 13             None           None         None   801007650  16020153
#
#    adapter_spec  avg_read_length assay
# 0          None             50.0   rna
# 1          None             50.0   rna
# 2          None             50.0   rna
# 3          None             50.0   rna
# 4          None             50.0   rna
# 5          None             50.0   rna
# 6          None             50.0   rna
# 7          None             50.0   rna
# 8          None             50.0   rna
# 9          None             50.0   rna
# 10         None             50.0   rna
# 11         None             50.0   rna
# 12         None             50.0   rna
# 13         None             50.0   rna

# %%
srp = 'SRP102020'
df = db.sra_metadata(srp)
df['assay'] = 'rna'
df = expand_sample_attribute_columns(df)
df.loc[df.experiment_title.str.contains('ribo'), 'assay'] = 'ribo'
df.to_csv('./results/{}_runtable.tsv'.format(srp), header=True, index=False, sep='\t')
all_dfs[srp] = df
df
# Out:
#   study_accession experiment_accession  \
# 0       SRP102020           SRX2647160
# 1       SRP102020           SRX2647161
# 2       SRP102020           SRX2647162
# 3       SRP102020           SRX2647163
#
#                                     experiment_title  \
# 0      GSM2538879: MCF7.C.rna; Homo sapiens; RNA-Seq
# 1  GSM2538882: MCF7.Nutlin.rna; Homo sapiens; RNA...
# 2       GSM2538884: MCF7.C.ribo; Homo sapiens; OTHER
# 3  GSM2538886: MCF7.Nutlin.ribo; Homo sapiens; OTHER
#
#         experiment_attribute  \
# 0  GEO Accession: GSM2538879
# 1  GEO Accession: GSM2538882
# 2  GEO Accession: GSM2538884
# 3  GEO Accession: GSM2538886
#
#                                     sample_attribute run_accession  taxon_id  \
# 0  source_name: MCF7 || cell line: MCF7 || treatm...    SRR5350738      9606
# 1  source_name: MCF7 || cell line: MCF7 || treatm...    SRR5350739      9606
# 2  source_name: MCF7 || cell line: MCF7 || treatm...    SRR5350740      9606
# 3  source_name: MCF7 || cell line: MCF7 || treatm...    SRR5350741      9606
#
#   library_selection library_layout library_strategy  library_source  \
# 0              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 1              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 2             other      SINGLE -             OTHER  TRANSCRIPTOMIC
# 3             other      SINGLE -             OTHER  TRANSCRIPTOMIC
#
#   library_name       bases      spots adapter_spec  avg_read_length assay  \
# 0         None  2440001874   47843174         None             51.0   rna
# 1         None  2179008048   42725648         None             51.0   rna
# 2         None  6207104124  121707924         None             51.0  ribo
# 3         None  7039554786  138030486         None             51.0  ribo
#
#   cell_line source_name treatment
# 0      mcf7        mcf7   control
# 1      mcf7        mcf7  nutlin3a
# 2      mcf7        mcf7   control
# 3      mcf7        mcf7  nutlin3a

# %%
writer = pd.ExcelWriter('./results/{}_datasets_runtable.xlsx'.format(assembly_common_name_map[sheet_name]), engine='xlsxwriter')
for sheet_name, df in all_dfs.items():
    df.to_excel(writer, sheet_name=sheet_name, index=False)
writer.save()
